# %%
# default_exp core

# %% [markdown]
# # Demo Project
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
#export
def say_hi(to):
    "Enthusiastically say hi to someone"
    return f'Hii {to}!'

# %%
say_hi("Minh")
# Out:
# 'Hii Minh!'
